# %%
import os
import sys
import hashlib

# !pip install tensorflow_addons
# !pip install rdkit
# !pip install keras-swa

import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
import keras.backend as K
from tensorflow.keras import layers
from swa.tfkeras import SWA

from custom_loss import rwrmse, alpha_1point75, alpha_1point5, alpha_1point25, alpha_adaptive, cauchy

import math as m
import numpy as np
import pandas as pd
import warnings

from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import AllChem
from rdkit.Chem import RDKFingerprint

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import resample
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.22.0 typeguard-2.13.3
# Collecting rdkit
#   Downloading rdkit-2023.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.1
# Collecting keras-swa
#   Downloading keras-swa-0.1.7.tar.gz (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: keras-swa
#   Building wheel for keras-swa (setup.py) ... done
#   Created wheel for keras-swa: filename=keras_swa-0.1.7-py3-none-any.whl size=7823 sha256=a8eeaa7e325ec29572b3e8e5ac564907fe84607251e133d5ee2d0a0c78dda8be
#   Stored in directory: /root/.cache/pip/wheels/1f/f3/68/48c5eb0509cd523f1c975e1240ae3d97540f6e2666bcdedae4
# Successfully built keras-swa
# Installing collected packages: keras-swa
# Successfully installed keras-swa-0.1.7
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# Set random seeds
np.random.seed(8)
tf.random.set_seed(8)

# %%
# Load training data
train_path = '/content/drive/MyDrive/Colab Notebooks/Input/singlecell/de_train.parquet'
df_train = pd.read_parquet(train_path)

# %%
# Get Morgan fingerprints
df_X = np.zeros([df_train.shape[0], 2048])
for i in range(df_train.shape[0]):
	df_X[i, :] = np.array(AllChem.GetMorganFingerprintAsBitVect(Chem.MolFromSmiles(df_train["SMILES"][i]), radius=2, nBits=2048))

# %%
# Truncation function
def truncator(max, min, targets):
	return targets.clip(min, max)

# %%
# Jaccard similiarty
def jaccard_binary(x, y):
    intersection = np.logical_and(x, y)
    union = np.logical_or(x, y)
    similarity = intersection.sum() / float(union.sum())
    return similarity

# %%
# One hot encode the cells
# One hot ordering: [B cells,  Myeloid cells,  NK cells,  T cells CD4+,  T cells CD8+,  T regulatory cells]
one_hot = np.array(pd.get_dummies(df_train["cell_type"]) * 1.0)

# %%
# One hot encode controls
# 1 - control, 0 - otherwise
# 12 control observations, 2 per cell type
train_control = np.zeros([df_train.shape[0], 1])
for i, cont in enumerate(df_train["control"]):
  if cont == True:
    train_control[i] = 1.

# %%
# Get log p values for train set
df_chem = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Input/singlecell/chemical_properties.csv')
# Apply Log10 transform to n_atoms, molecular weight, and molar refractivity
df_chem["n_atoms"] = df_chem["n_atoms"].map(np.log10)
df_chem["mol_weight"] = df_chem["mol_weight"].map(np.log10)
df_chem["MR"] = df_chem["MR"].map(np.log10)

# %%
# Get dose values
# Controls: Dabrafenib - 1 uM dose, Belinostat - 0.1 uM dose
# All non-control doses are 1 uM
df_logfc = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/Input/singlecell/logFC.parquet')
train_dose = np.array(df_logfc["dose_uM"]).reshape((df_train.shape[0], 1))

# %%
# Scale data
scaler = StandardScaler()
scaler.fit(df_chem[["log_P", "MR"]])
# Out:
# StandardScaler()

# %%
# Join to form training matrix
one_hot = np.concatenate((one_hot, scaler.transform(df_chem[["log_P", "MR"]]), train_control), axis=1)
x_train = np.concatenate((one_hot, df_X), axis=1)

# %%
x_train.shape
# Out:
# (614, 2057)

# %%
# Make train data and targets
n_genes = 18211
y_train = np.array(df_train.iloc[:, 5:])

# %%
# Get log FC
y_logfc = np.array(df_logfc.iloc[:, 7:])

# %%
# Remove control samples. Takes out rows with cell type and compound exposure used as control
# Removing control also reduced the outliers
remove_control = False
if remove_control:
	control_false = list(df_train.index[df_train["control"] == False])
	# x_train and y_train
	x_train = x_train[control_false, :]
	y_train = y_train[control_false, :]
	# df_train
	df_train = df_train[df_train["control"] == False]

# %%
# Load in NN derived chemical weights (probabilities)
chem_weights = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Input/singlecell/train_chem_prob.csv')
chem_weights = np.array(chem_weights)

# %%
# Get weights for each cell type, calculated in separate file
# Calculated with log base of 1.5
cell_sample_weights = True
cell_sample_weights_scaling = False

# Chemical sample weighting
chem_sample_weights = False

if cell_sample_weights:
  # Change weight dict as necessary
  # Original Frobenius norm weight dictionary
  # weight_dict = {'B cells': 1., 'Myeloid cells': 1., 'T regulatory cells': 0.6518986684331918, 'T cells CD8+': 0.7203918421401994, 'NK cells': 0.7519447057731612, 'T cells CD4+': 0.6866328017001024}
  # Using cosine similarity weights
  weight_dict = {'B cells': 1., 'Myeloid cells': 1., 'NK cells': 0.3198791742324829, 'T cells CD8+': 0.05635642260313034, 'T cells CD4+': 0.24452143907546997, 'T regulatory cells': 0.21414318680763245}
  scaling_factor = {'T regulatory cells': 1.0718517636591396, 'T cells CD8+': 1.0950687072395096, 'NK cells': 1.1118585488618329, 'T cells CD4+': 1.0843393196219417}
  # Create weight vector
  # Assign a weight of 1 to B cells and Myeloid cells
  sample_weights = []
  for cell_type in df_train["cell_type"]:
    if cell_type in ["B cells", "Myeloid cells"]:
      sample_weights.append(1.0)
    else:
      sample_weights.append(weight_dict[cell_type])
  # Divide by minimum weight
  sample_weights /= np.min(sample_weights)
  if cell_sample_weights_scaling:
    for i, cell_type in enumerate(df_train["cell_type"]):
      if cell_type in ["B cells", "Myeloid cells"]:
        sample_weights[i] *= 1.0
      else:
        sample_weights[i] *= scaling_factor[cell_type]
  # 2 decimals
  sample_weights = np.around(sample_weights, 2)

if chem_sample_weights:
# Sum first two columns for each row of probabilities (p(private) + p(public))
# Predicted cells are not paired with compounds in test set, add score of 1.0 to still boost importance of focus on cell type
# Cells which are not in test and where compounds are not in test have no gained scores
  chem_weights_norm = []
  for i in range(df_X.shape[0]):
    chem_weights_norm.append(np.sum(chem_weights[i, :2])/chem_weights[i, 2])
  # Normalise to 1.0
  chem_weights_norm /= np.max(chem_weights_norm)
  # Assign weights to sample_weights
  for i in range(df_X.shape[0]):
    cell_type = df_train["cell_type"][i]
    if cell_type in ["B cells", "Myeloid cells"]:
      sample_weights[i] += chem_weights_norm[i] # Alternative: (chem_weights_norm[i] + 1.)
    else:
      sample_weights[i] += chem_weights_norm[i]
  # 2 decimals
  sample_weights = np.around(sample_weights, 2)

sample_weights
# Out:
# array([ 5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74,
#        17.74,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#        17.74, 17.74,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,
#         4.34,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 , 17.74, 17.74,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74,
#        17.74,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,  5.68,  4.34,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 , 17.74, 17.74,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,
#         3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,
#         4.34,  1.  ,  3.8 ,  5.68,  4.34,  1.  ,  3.8 ,  5.68,  4.34,
#         1.  ,  3.8 ])

# %%
np.min(y_train)
# Out:
# -180.5192016034818

# %%
np.max(y_train)
# Out:
# 179.32417689610105

# %%
# Get y_pv, y_sign transform y_train into -np.log1000(y_pv) * sign(LFC)
y_pv = 10 ** (-np.abs(y_train))
y_train_log1000 = -(np.log10(y_pv) / 3.0) * np.sign(y_train)

# %%
np.max(y_train_log1000), np.min(y_train_log1000)
# Out:
# (59.774725632033686, -60.1730672011606)

# %%
# Gavish Donohoe SVD dimension reduction, returns q, U, S, VT
def gd_svd(data_mat, cutoff="w_B_high"):
  U, S, VT = np.linalg.svd(data_mat, full_matrices=False)
  # Calculate aspect ratio and cutoff
  Beta = data_mat.shape[0] / data_mat.shape[1]
  # Approximate w(B)
  w_B = 0.56 * Beta ** 3 - 0.95 * Beta ** 2 + 1.82 * Beta + 1.43
  med_S = np.median(S)
  if cutoff == "w_B":
    tau = w_B * med_S
  elif cutoff == "w_B_low":
    w_B_low = w_B - 0.02
    tau = w_B_low * med_S
  elif cutoff == "w_B_high":
    w_B_high = w_B + 0.02
    tau = w_B_high * med_S
  # Get optimal modes
  q = np.max(np.where(S > tau))
  U, S, VT = U[:, :(q+1)], np.diag(S[:(q+1)]), VT[:(q+1), :]
  return q, U, S, VT

# %%
# Perform dimension reduction on y_train
run_svd = True
run_autoencoder = False

if run_svd:
  q, U, S, VT = gd_svd(data_mat=y_train, cutoff="w_B_high")

if run_autoencoder:
  encoding_dim = 115
  # Load in AE model
  ae_target = keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/AE Models/sign_logpv_autoencoder_linear_embed_600e_115.h5')
  # Encoder
  encoder = keras.Model(inputs=ae_target.input, outputs=ae_target.layers[7].output)
  # Decoder
  decoder = keras.Model(inputs=ae_target.layers[8].input, outputs=ae_target.layers[-1].output)

q
# Out:
# 113

# %%
# Get embeddings for y_train
if run_svd:
  # Calculate denoised y_train
  y_train_tilde = U @ S @ VT
  # Get y_embed
  y_embed = U @ S

if run_autoencoder:
  # Get y_embed
  y_embed = encoder.predict(y_train)

y_embed.shape
# Out:
# (614, 114)

# %%
# Perform SVD on logfc
if run_svd:
  k, U_lfc, S_lfc, VT_lfc = gd_svd(data_mat=y_logfc, cutoff="w_B_high")

k
# Out:
# 63

# %%
# Get embeddings for log FC
if run_svd:
  # Calculate embeddings as features
  y_embed_logfc = U_lfc @ S_lfc

# %%
np.max(y_embed), np.min(y_embed), np.max(y_embed_logfc), np.min(y_embed_logfc)
# Out:
# (788.468073666263, -2693.3554989721106, 268.0056428553899, -415.64380997423666)

# %%
x_train.shape, y_embed.shape, y_embed_logfc.shape
# Out:
# ((614, 2057), (614, 114), (614, 64))

# %%
# Standard scale SVD embed features
y_train_scale = True
scaler_type = "minmax" # or use "minmax"

if y_train_scale:
  if scaler_type == "standard_scaler":
    scaler_y_embed = StandardScaler()
    scaler_y_embed.fit(y_embed)
    y_embed = scaler_y_embed.transform(y_embed)
  elif scaler_type == "minmax":
    scaler_y_embed = MinMaxScaler(feature_range=(-15, 15)) # Scale SVD embeds to be centered around 0, try later -20, 20
    scaler_y_embed.fit(y_embed)
    y_embed = scaler_y_embed.transform(y_embed)

# %%
np.max(y_embed), np.min(y_embed)
# Out:
# (15.000000000000005, -15.0)

# %%
# Augment features with average drug response and average cell type response to drugs
# P-val responses
# Embedding features
embedding_features = False

# Drug response, cell type response
drug_response = False
cell_type_response = False
# Log FC response
drug_lfc_response = False
cell_type_lfc_response = False

if drug_response:
  scaler_drug = StandardScaler()
  if embedding_features:
    df_smiles_name = df_train.iloc[:, [3]]
    df_smiles_name = pd.concat((df_smiles_name, pd.DataFrame(y_embed)), axis=1) # Use SVD embeddings to average over
  else:
    # Normal dimension features
    df_smiles_name = df_train.iloc[:, [3] + list(range(5, df_train.shape[1]))]
  mean_smiles_name = df_smiles_name.groupby('SMILES').mean().reset_index()
  df_train_alt = df_train.iloc[:, 0:5]
  df_train_alt = df_train_alt.merge(mean_smiles_name, on='SMILES', how='left')
  mean_smiles_train = np.array(df_train_alt.iloc[:, 5:])
  # Fit and transform
  scaler_drug.fit(mean_smiles_train)
  # Concat with x_train
  x_train = np.concatenate((x_train, scaler_drug.transform(mean_smiles_train)), axis=1)

if cell_type_response:
  scaler_cell = StandardScaler()
  if embedding_features:
    df_cell_type = df_train.iloc[:, [0]]
    df_cell_type = pd.concat((df_cell_type, pd.DataFrame(y_embed)), axis=1)
  else:
    # Normal dimension features
    df_cell_type = df_train.iloc[:, [0] + list(range(5, df_train.shape[1]))]
  mean_cell_type = df_cell_type.groupby('cell_type').mean().reset_index()
  df_train_alt = df_train.iloc[:, 0:5]
  df_train_alt = df_train_alt.merge(mean_cell_type, on='cell_type', how='left')
  mean_cell_train = np.array(df_train_alt.iloc[:, 5:])
  # Fit and transform
  scaler_cell.fit(mean_cell_train)
  # Concat with x_train
  x_train = np.concatenate((x_train, scaler_cell.transform(mean_cell_train)), axis=1)

if drug_lfc_response:
  scaler_drug_lfc = StandardScaler()
  if embedding_features:
    df_smiles_name = df_train.iloc[:, [3]]
    df_smiles_name = pd.concat((df_smiles_name, pd.DataFrame(y_embed_logfc)), axis=1)
  else:
    # Normal dimension features
    df_smiles_name = df_train.iloc[:, [3]]
    df_smiles_name = pd.concat((df_smiles_name, df_logfc.iloc[:, 7:]), axis=1)
  mean_smiles_lfc_name = df_smiles_name.groupby('SMILES').mean().reset_index()
  df_train_alt = df_train.iloc[:, 0:5]
  df_train_alt = df_train_alt.merge(mean_smiles_lfc_name, on='SMILES', how='left')
  mean_smiles_lfc_train = np.array(df_train_alt.iloc[:, 5:])
  # Fit and transform
  scaler_drug_lfc.fit(mean_smiles_lfc_train)
  # Concat with x_train
  x_train = np.concatenate((x_train, scaler_drug_lfc.transform(mean_smiles_lfc_train)), axis=1)

if cell_type_lfc_response:
  scaler_cell_lfc = StandardScaler()
  if embedding_features:
    df_cell_type = df_train.iloc[:, [0]]
    df_cell_type = pd.concat((df_cell_type, pd.DataFrame(y_embed_logfc)), axis=1)
  else:
    # Normal dimension features
    df_cell_type = df_train.iloc[:, [0]]
    df_cell_type = pd.concat((df_cell_type, df_logfc.iloc[:, 7:]), axis=1)
  mean_cell_lfc_type = df_cell_type.groupby('cell_type').mean().reset_index()
  df_train_alt = df_train.iloc[:, 0:5]
  df_train_alt = df_train_alt.merge(mean_cell_lfc_type, on='cell_type', how='left')
  mean_cell_lfc_train = np.array(df_train_alt.iloc[:, 5:])
  # Fit and transform
  scaler_cell_lfc.fit(mean_cell_lfc_train)
  # Concat with x_train
  x_train = np.concatenate((x_train, scaler_cell_lfc.transform(mean_cell_lfc_train)), axis=1)

# %%
# Keep copy of x_train in original row order wrt df_train
x_train_copy = x_train
y_train_copy = y_train
y_embed_copy = y_embed

# %%
# Upsampling based on weights
# one hot encoding: B cells,	Myeloid cells,	NK cells,	T cells CD4+,	T cells CD8+,	T regulatory cells
upsample = False

if upsample:
  # Correct order of cells as in x_train
  cell_types = ['B cells', 'Myeloid cells', 'NK cells', 'T cells CD4+', 'T cells CD8+', 'T regulatory cells']
  min_weight = min(list(weight_dict.values()))
  for i in range(len(cell_types)):
    # Don't resample control observations
    idx_list = np.where((x_train[:, i] == 1) & (x_train[:, 8] == 0))[0]
    base_train = x_train[idx_list, :]
    print(base_train.shape)
    base_target = y_embed[idx_list, :]
    # Scaling factor
    n_sample = int((np.around(weight_dict[cell_types[i]]/min_weight, 2) - 1) * base_train.shape[0])
    print(n_sample)
    # Sample and append to x_train, y_embed
    if n_sample > 0:
      # If no sampling, don't concat
      sample_train, sample_target = resample(base_train, base_target, n_samples=n_sample, replace=True, random_state=8)
      # Concat
      x_train = np.concatenate((x_train, sample_train), axis=0)
      y_embed = np.concatenate((y_embed, sample_target), axis=0)

# %%
x_train.shape
# Out:
# (614, 2057)

# %%
# Shuffle data
permuted_indices = np.random.permutation(np.arange(x_train.shape[0]))
if upsample:
  # Only permute train, target if upsampling
  x_train = x_train[permuted_indices, :]
  y_embed = y_embed[permuted_indices, :]
else:
  # Otherwise permute sample weights as well
  x_train = x_train[permuted_indices, :]
  y_embed = y_embed[permuted_indices, :]
  y_train = y_train[permuted_indices, :]
  sample_weights = sample_weights[permuted_indices]

# %%
sample_weights
# Out:
# array([ 3.8 ,  1.  ,  3.8 ,  5.68,  4.34,  3.8 ,  4.34,  3.8 ,  3.8 ,
#         3.8 ,  4.34,  1.  ,  1.  ,  4.34,  4.34,  3.8 ,  1.  ,  3.8 ,
#         5.68,  4.34,  1.  ,  4.34,  3.8 ,  1.  ,  3.8 ,  5.68, 17.74,
#         4.34,  5.68,  3.8 ,  4.34,  5.68,  1.  ,  3.8 ,  3.8 ,  3.8 ,
#         3.8 ,  1.  ,  5.68,  4.34,  1.  ,  3.8 ,  3.8 ,  1.  ,  5.68,
#         5.68,  4.34,  1.  ,  3.8 ,  1.  ,  4.34,  4.34,  3.8 ,  4.34,
#         4.34,  4.34,  4.34,  3.8 ,  4.34,  3.8 ,  4.34,  5.68,  5.68,
#         3.8 ,  1.  ,  1.  , 17.74,  5.68,  1.  ,  3.8 , 17.74,  1.  ,
#         5.68,  3.8 , 17.74,  1.  ,  1.  ,  3.8 ,  5.68,  5.68,  3.8 ,
#         3.8 ,  3.8 ,  5.68,  4.34,  3.8 ,  5.68,  4.34,  5.68,  3.8 ,
#         1.  ,  1.  ,  1.  ,  3.8 ,  1.  ,  4.34,  4.34,  3.8 ,  5.68,
#         1.  , 17.74,  3.8 ,  1.  ,  3.8 ,  3.8 ,  5.68,  1.  , 17.74,
#         3.8 ,  1.  ,  5.68,  5.68,  3.8 ,  3.8 ,  1.  ,  4.34,  3.8 ,
#         4.34,  5.68,  1.  ,  5.68,  1.  ,  4.34, 17.74, 17.74,  1.  ,
#         1.  ,  3.8 ,  4.34,  1.  ,  1.  ,  3.8 , 17.74, 17.74,  1.  ,
#         3.8 ,  3.8 ,  1.  ,  5.68,  3.8 ,  4.34,  1.  ,  1.  ,  3.8 ,
#         1.  ,  4.34,  5.68,  4.34,  1.  ,  1.  ,  5.68,  4.34,  3.8 ,
#         3.8 ,  4.34,  4.34,  1.  ,  4.34,  3.8 ,  1.  ,  4.34,  4.34,
#         5.68,  4.34,  1.  ,  4.34,  5.68,  1.  ,  1.  ,  3.8 ,  4.34,
#         4.34,  3.8 ,  5.68,  4.34,  4.34,  5.68,  4.34,  5.68,  5.68,
#         4.34,  4.34,  5.68,  3.8 ,  4.34,  1.  ,  4.34,  1.  ,  5.68,
#         4.34,  1.  , 17.74,  4.34,  3.8 , 17.74,  3.8 ,  1.  ,  1.  ,
#         3.8 ,  5.68,  3.8 ,  5.68,  3.8 ,  3.8 ,  4.34,  1.  ,  5.68,
#         4.34, 17.74,  3.8 ,  1.  ,  3.8 ,  5.68,  1.  ,  1.  ,  1.  ,
#         3.8 ,  4.34,  1.  ,  1.  ,  5.68,  3.8 ,  4.34,  5.68,  3.8 ,
#         1.  ,  5.68,  4.34,  4.34,  1.  ,  1.  ,  3.8 ,  3.8 ,  4.34,
#         3.8 ,  4.34,  5.68,  4.34,  3.8 ,  4.34,  5.68,  5.68,  5.68,
#         1.  ,  3.8 ,  5.68,  5.68,  3.8 ,  4.34,  4.34,  5.68, 17.74,
#         1.  ,  5.68,  4.34,  1.  ,  5.68,  4.34,  1.  ,  3.8 , 17.74,
#         3.8 ,  3.8 , 17.74,  4.34,  5.68,  3.8 ,  1.  ,  1.  , 17.74,
#         3.8 ,  5.68,  1.  ,  4.34,  5.68,  5.68,  3.8 ,  5.68,  4.34,
#         3.8 , 17.74,  1.  ,  3.8 ,  5.68,  5.68,  5.68,  4.34,  4.34,
#         3.8 ,  4.34,  4.34,  4.34,  1.  ,  4.34,  4.34,  3.8 ,  4.34,
#         5.68,  3.8 ,  1.  ,  4.34,  4.34,  4.34,  1.  ,  3.8 ,  3.8 ,
#         1.  ,  1.  ,  5.68,  5.68,  4.34,  3.8 ,  4.34,  5.68,  3.8 ,
#         4.34,  4.34,  4.34,  1.  ,  5.68,  1.  ,  1.  ,  3.8 ,  1.  ,
#         1.  ,  1.  ,  4.34,  1.  ,  3.8 ,  3.8 ,  5.68,  5.68,  1.  ,
#         1.  ,  1.  ,  4.34,  1.  ,  1.  , 17.74,  5.68,  3.8 ,  5.68,
#         5.68,  5.68,  1.  ,  3.8 ,  4.34,  5.68,  3.8 ,  4.34,  1.  ,
#         4.34,  5.68,  5.68,  5.68,  5.68,  5.68,  3.8 ,  1.  ,  5.68,
#         1.  ,  3.8 ,  1.  ,  5.68,  5.68,  1.  ,  5.68,  3.8 , 17.74,
#         1.  ,  5.68,  3.8 ,  1.  ,  1.  , 17.74,  3.8 ,  1.  ,  4.34,
#         1.  , 17.74,  3.8 , 17.74,  5.68,  5.68,  5.68,  4.34, 17.74,
#         5.68,  4.34,  5.68,  4.34,  3.8 ,  4.34,  4.34,  4.34,  5.68,
#         5.68,  1.  ,  4.34,  5.68,  3.8 ,  1.  ,  4.34,  3.8 ,  3.8 ,
#        17.74,  5.68,  3.8 ,  1.  ,  5.68, 17.74,  1.  ,  5.68,  5.68,
#         5.68, 17.74,  1.  ,  5.68,  5.68,  3.8 ,  3.8 ,  1.  ,  5.68,
#         5.68,  4.34,  3.8 ,  4.34,  4.34,  5.68, 17.74,  1.  ,  5.68,
#         5.68,  3.8 ,  5.68,  5.68,  1.  ,  5.68,  3.8 ,  1.  ,  5.68,
#         4.34,  5.68,  4.34,  1.  ,  1.  ,  5.68,  4.34,  3.8 ,  3.8 ,
#         4.34,  5.68,  1.  ,  1.  ,  3.8 ,  3.8 ,  3.8 ,  5.68,  3.8 ,
#         4.34,  4.34,  1.  , 17.74,  4.34,  3.8 ,  4.34,  1.  ,  3.8 ,
#         1.  ,  5.68,  3.8 ,  3.8 , 17.74,  5.68,  5.68,  3.8 ,  4.34,
#        17.74,  4.34,  5.68,  4.34,  5.68,  1.  ,  4.34,  3.8 ,  5.68,
#         4.34,  3.8 ,  3.8 ,  3.8 ,  3.8 ,  1.  ,  1.  ,  1.  ,  4.34,
#         4.34,  4.34,  4.34,  5.68,  3.8 ,  4.34,  4.34,  4.34,  1.  ,
#         5.68,  5.68,  5.68,  5.68,  4.34,  4.34,  1.  ,  5.68, 17.74,
#         1.  ,  4.34,  3.8 , 17.74,  3.8 ,  4.34,  4.34,  4.34,  4.34,
#         3.8 ,  5.68,  5.68,  5.68,  1.  ,  5.68,  5.68,  5.68,  4.34,
#         5.68,  4.34,  4.34,  1.  ,  3.8 ,  4.34,  1.  ,  3.8 ,  3.8 ,
#         3.8 ,  5.68,  5.68,  4.34,  3.8 ,  5.68,  1.  ,  5.68,  4.34,
#         4.34,  5.68,  1.  ,  4.34,  3.8 ,  3.8 ,  1.  ,  5.68,  5.68,
#        17.74,  3.8 ,  5.68,  4.34,  4.34,  1.  ,  3.8 ,  3.8 ,  3.8 ,
#         1.  ,  4.34,  4.34,  3.8 ,  3.8 ,  5.68,  4.34,  1.  ,  5.68,
#         5.68,  4.34,  1.  ,  5.68,  1.  ,  5.68,  1.  ,  4.34,  1.  ,
#         4.34,  5.68,  4.34,  5.68,  1.  ,  3.8 ,  3.8 ,  1.  ,  5.68,
#         1.  ,  1.  ,  4.34,  3.8 ,  3.8 ,  3.8 ,  3.8 ,  5.68,  1.  ,
#         1.  ,  3.8 ,  1.  ,  1.  ,  4.34,  5.68,  3.8 ,  4.34,  5.68,
#         1.  ,  1.  ])

# %%
x_train.shape, y_train.shape, y_embed.shape
# Out:
# ((614, 2057), (614, 18211), (614, 114))

# %%
# Model
# Architecture selection
skip_connections = False
selu_stack = True

# Skip connections model
if skip_connections:
  input_size = x_train.shape[1]
  inputs_reg = layers.Input((input_size,))
  x_1 = layers.Dense(3072, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(inputs_reg)
  x_2 = layers.Dense(3072, kernel_initializer="lecun_normal", bias_initializer="zeros")(x_1)
  concat_1 = layers.Concatenate(axis=1)([inputs_reg, x_2])
  selu_1 = layers.Activation(keras.activations.selu)(concat_1)
  x_3 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(selu_1)
  x_4 = layers.Dense(5128, kernel_initializer="lecun_normal", bias_initializer="zeros")(x_3)
  add_1 = layers.Add()([selu_1, x_4])
  selu_2 = layers.Activation(keras.activations.selu)(add_1)
  x_5 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(selu_2)
  x_6 = layers.Dense(5128, kernel_initializer="lecun_normal", bias_initializer="zeros")(x_5)
  add_2 = layers.Add()([selu_2, x_6])
  selu_3 = layers.Activation(keras.activations.selu)(add_2)
  x_7 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(selu_3)
  x_8 = layers.Dense(5128, kernel_initializer="lecun_normal", bias_initializer="zeros")(x_7)
  add_3 = layers.Add()([selu_3, x_8])
  selu_4 = layers.Activation(keras.activations.selu)(add_3)
  x_9 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(selu_4)
  if run_svd:
    output_reg = layers.Dense((q+1), kernel_initializer="glorot_normal")(x_9)
  if run_autoencoder:
    output_reg = layers.Dense(encoding_dim, kernel_initializer="glorot_normal")(x_9)

# SELU stack
if selu_stack:
  input_size = x_train.shape[1]
  inputs_reg = layers.Input((input_size,))
  x_1 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(inputs_reg)
  x_2 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(x_1)
  x_3 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(x_2)
  x_4 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(x_3)
  x_5 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(x_4)
  x_6 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(x_5)
  x_7 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(x_6)
  x_8 = layers.Dense(5128, activation="selu", kernel_initializer="lecun_normal", bias_initializer="zeros")(x_7)
  if run_svd:
    output_reg = layers.Dense((q+1), kernel_initializer="glorot_normal")(x_8)
  if run_autoencoder:
    output_reg = layers.Dense(encoding_dim, kernel_initializer="glorot_normal")(x_8)

# Define model
model = keras.Model(inputs=inputs_reg, outputs=output_reg)

# %%
# Define losses
mae = keras.losses.MeanAbsoluteError()
mse = keras.losses.MeanSquaredError()
huber = keras.losses.Huber()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2057)]            0
#
#  dense (Dense)               (None, 5128)              10553424
#
#  dense_1 (Dense)             (None, 5128)              26301512
#
#  dense_2 (Dense)             (None, 5128)              26301512
#
#  dense_3 (Dense)             (None, 5128)              26301512
#
#  dense_4 (Dense)             (None, 5128)              26301512
#
#  dense_5 (Dense)             (None, 5128)              26301512
#
#  dense_6 (Dense)             (None, 5128)              26301512
#
#  dense_7 (Dense)             (None, 5128)              26301512
#
#  dense_8 (Dense)             (None, 114)               584706
#
# =================================================================
# Total params: 195248714 (744.81 MB)
# Trainable params: 195248714 (744.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Stochastic weight averaging
# SWA lr 5e-5 for constant
start_epoch = 601
swa = SWA(start_epoch=start_epoch,
          lr_schedule='manual',
          verbose=1)

# Optimizer
# Best scores used learning rate 7e-5, 5e-5, 3.5e-5
learning_rate = 7e-5

# Cosine rate scheduler
# Every 7800 steps, 200 epochs. Cosine Decay changes LR each batch (step)
# Every 3900 steps, 100 epochs
cos_sched = keras.optimizers.schedules.CosineDecayRestarts(initial_learning_rate=learning_rate, first_decay_steps=7800, t_mul=1.0, m_mul=0.9, alpha=0.01)

# Optimisers
# Try higher weight decay for larger models
# lambda = lambda(norm) * sqrt(batch_size / (n * t)), where n is number of training points and t is number of epochs
# Where cosine warm restarts is used t, is the number of epochs in a restart period. For long trains use t as the epochs in the last restart
# Try lambda(norm) between 0.025 to 0.05
weight_decay = 5e-4 # Try 2.8e-4 for lambda_norm = 0.025, and 5.6e-4 for lambda_norm = 0.05 and 4.2e-4 for lambda_norm = 0.0375

opt_adam = keras.optimizers.Adam(learning_rate=cos_sched)

opt_adamW = keras.optimizers.AdamW(learning_rate=cos_sched) # Weight decay not set

opt_adaMax = keras.optimizers.Adamax(learning_rate=cos_sched, weight_decay=weight_decay)

# %%
# Compile model
model.compile(loss=mae, optimizer=opt_adamW, metrics=[mae, rwrmse])

# Train model # no sample weights
model.fit(x=x_train, y=y_embed, epochs=800, batch_size=16, callbacks=[swa], shuffle=True)
# Out:
# Epoch 1/800
#  6/39 [===>..........................] - ETA: 2s - loss: 2.4398 - mean_absolute_error: 2.4398 - rwrmse: 3.1394
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0328s vs `on_train_batch_end` time: 0.0398s). Check your callbacks.
# 39/39 [==============================] - 11s 80ms/step - loss: 2.0142 - mean_absolute_error: 2.0146 - rwrmse: 2.7102
# Epoch 2/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.5859 - mean_absolute_error: 1.5890 - rwrmse: 2.2416
# Epoch 3/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.4633 - mean_absolute_error: 1.4625 - rwrmse: 2.1149
# Epoch 4/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4101 - mean_absolute_error: 1.4260 - rwrmse: 2.0744
# Epoch 5/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4039 - mean_absolute_error: 1.4041 - rwrmse: 2.0487
# Epoch 6/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.3648 - mean_absolute_error: 1.3637 - rwrmse: 2.0019
# Epoch 7/800
# 39/39 [==============================] - 3s 83ms/step - loss: 1.3254 - mean_absolute_error: 1.3193 - rwrmse: 1.9399
# Epoch 8/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.3156 - mean_absolute_error: 1.3128 - rwrmse: 1.9298
# Epoch 9/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2617 - mean_absolute_error: 1.2595 - rwrmse: 1.8498
# Epoch 10/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2442 - mean_absolute_error: 1.2392 - rwrmse: 1.7992
# Epoch 11/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.1716 - mean_absolute_error: 1.1686 - rwrmse: 1.6899
# Epoch 12/800
# 39/39 [==============================] - 3s 83ms/step - loss: 1.1309 - mean_absolute_error: 1.1278 - rwrmse: 1.6240
# Epoch 13/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.0854 - mean_absolute_error: 1.0812 - rwrmse: 1.5558
# Epoch 14/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.0521 - mean_absolute_error: 1.0604 - rwrmse: 1.5213
# Epoch 15/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.0743 - mean_absolute_error: 1.0753 - rwrmse: 1.5275
# Epoch 16/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.0335 - mean_absolute_error: 1.0370 - rwrmse: 1.4748
# Epoch 17/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9820 - mean_absolute_error: 0.9871 - rwrmse: 1.4020
# Epoch 18/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.9547 - mean_absolute_error: 0.9548 - rwrmse: 1.3575
# Epoch 19/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9065 - mean_absolute_error: 0.9042 - rwrmse: 1.2833
# Epoch 20/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.8780 - mean_absolute_error: 0.8755 - rwrmse: 1.2479
# Epoch 21/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.8509 - mean_absolute_error: 0.8499 - rwrmse: 1.2118
# Epoch 22/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8238 - mean_absolute_error: 0.8275 - rwrmse: 1.1825
# Epoch 23/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8478 - mean_absolute_error: 0.8452 - rwrmse: 1.1974
# Epoch 24/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8132 - mean_absolute_error: 0.8096 - rwrmse: 1.1539
# Epoch 25/800
# 39/39 [==============================] - 3s 83ms/step - loss: 0.7799 - mean_absolute_error: 0.7790 - rwrmse: 1.1082
# Epoch 26/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7658 - mean_absolute_error: 0.7620 - rwrmse: 1.0778
# Epoch 27/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.7413 - mean_absolute_error: 0.7440 - rwrmse: 1.0615
# Epoch 28/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.7436 - mean_absolute_error: 0.7433 - rwrmse: 1.0499
# Epoch 29/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.7076 - mean_absolute_error: 0.7056 - rwrmse: 1.0020
# Epoch 30/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6910 - mean_absolute_error: 0.6923 - rwrmse: 0.9836
# Epoch 31/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6860 - mean_absolute_error: 0.6857 - rwrmse: 0.9711
# Epoch 32/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6675 - mean_absolute_error: 0.6656 - rwrmse: 0.9468
# Epoch 33/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6450 - mean_absolute_error: 0.6478 - rwrmse: 0.9196
# Epoch 34/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6329 - mean_absolute_error: 0.6343 - rwrmse: 0.8963
# Epoch 35/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6257 - mean_absolute_error: 0.6253 - rwrmse: 0.8838
# Epoch 36/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6256 - mean_absolute_error: 0.6236 - rwrmse: 0.8801
# Epoch 37/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.5899 - mean_absolute_error: 0.5905 - rwrmse: 0.8349
# Epoch 38/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.5791 - mean_absolute_error: 0.5760 - rwrmse: 0.8067
# Epoch 39/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.5665 - mean_absolute_error: 0.5656 - rwrmse: 0.7978
# Epoch 40/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.5585 - mean_absolute_error: 0.5714 - rwrmse: 0.8064
# Epoch 41/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.5676 - mean_absolute_error: 0.5700 - rwrmse: 0.7979
# Epoch 42/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.5442 - mean_absolute_error: 0.5420 - rwrmse: 0.7561
# Epoch 43/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.5200 - mean_absolute_error: 0.5184 - rwrmse: 0.7245
# Epoch 44/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.5161 - mean_absolute_error: 0.5185 - rwrmse: 0.7277
# Epoch 45/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.5121 - mean_absolute_error: 0.5177 - rwrmse: 0.7233
# Epoch 46/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.5134 - mean_absolute_error: 0.5128 - rwrmse: 0.7093
# Epoch 47/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.5041 - mean_absolute_error: 0.5022 - rwrmse: 0.6959
# Epoch 48/800
# 39/39 [==============================] - 3s 83ms/step - loss: 0.4811 - mean_absolute_error: 0.4800 - rwrmse: 0.6630
# Epoch 49/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.4798 - mean_absolute_error: 0.4808 - rwrmse: 0.6641
# Epoch 50/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.4744 - mean_absolute_error: 0.4746 - rwrmse: 0.6513
# Epoch 51/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.4633 - mean_absolute_error: 0.4614 - rwrmse: 0.6318
# Epoch 52/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.4435 - mean_absolute_error: 0.4437 - rwrmse: 0.6068
# Epoch 53/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.4468 - mean_absolute_error: 0.4466 - rwrmse: 0.6142
# Epoch 54/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.4315 - mean_absolute_error: 0.4341 - rwrmse: 0.5934
# Epoch 55/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.4353 - mean_absolute_error: 0.4377 - rwrmse: 0.5971
# Epoch 56/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.4468 - mean_absolute_error: 0.4468 - rwrmse: 0.6031
# Epoch 57/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.4339 - mean_absolute_error: 0.4355 - rwrmse: 0.5911
# Epoch 58/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.4115 - mean_absolute_error: 0.4097 - rwrmse: 0.5535
# Epoch 59/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.4038 - mean_absolute_error: 0.4018 - rwrmse: 0.5412
# Epoch 60/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.4104 - mean_absolute_error: 0.4091 - rwrmse: 0.5541
# Epoch 61/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.3923 - mean_absolute_error: 0.3937 - rwrmse: 0.5303
# Epoch 62/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.3860 - mean_absolute_error: 0.3864 - rwrmse: 0.5202
# Epoch 63/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3853 - mean_absolute_error: 0.3842 - rwrmse: 0.5189
# Epoch 64/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3868 - mean_absolute_error: 0.3853 - rwrmse: 0.5168
# Epoch 65/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.3776 - mean_absolute_error: 0.3766 - rwrmse: 0.5036
# Epoch 66/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.3644 - mean_absolute_error: 0.3649 - rwrmse: 0.4905
# Epoch 67/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.3617 - mean_absolute_error: 0.3614 - rwrmse: 0.4847
# Epoch 68/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3628 - mean_absolute_error: 0.3631 - rwrmse: 0.4857
# Epoch 69/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3503 - mean_absolute_error: 0.3486 - rwrmse: 0.4653
# Epoch 70/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.3489 - mean_absolute_error: 0.3493 - rwrmse: 0.4673
# Epoch 71/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.3458 - mean_absolute_error: 0.3446 - rwrmse: 0.4570
# Epoch 72/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3309 - mean_absolute_error: 0.3329 - rwrmse: 0.4439
# Epoch 73/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.3312 - mean_absolute_error: 0.3294 - rwrmse: 0.4360
# Epoch 74/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.3145 - mean_absolute_error: 0.3138 - rwrmse: 0.4178
# Epoch 75/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.3169 - mean_absolute_error: 0.3189 - rwrmse: 0.4234
# Epoch 76/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.3472 - mean_absolute_error: 0.3469 - rwrmse: 0.4632
# Epoch 77/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3378 - mean_absolute_error: 0.3362 - rwrmse: 0.4472
# Epoch 78/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3231 - mean_absolute_error: 0.3238 - rwrmse: 0.4357
# Epoch 79/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.3251 - mean_absolute_error: 0.3238 - rwrmse: 0.4299
# Epoch 80/800
# 39/39 [==============================] - 3s 88ms/step - loss: 0.3152 - mean_absolute_error: 0.3141 - rwrmse: 0.4187
# Epoch 81/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3129 - mean_absolute_error: 0.3119 - rwrmse: 0.4156
# Epoch 82/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.3132 - mean_absolute_error: 0.3126 - rwrmse: 0.4170
# Epoch 83/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.3005 - mean_absolute_error: 0.2988 - rwrmse: 0.3980
# Epoch 84/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.2965 - mean_absolute_error: 0.2947 - rwrmse: 0.3919
# Epoch 85/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.2906 - mean_absolute_error: 0.2927 - rwrmse: 0.3901
# Epoch 86/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2891 - mean_absolute_error: 0.2885 - rwrmse: 0.3835
# Epoch 87/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2850 - mean_absolute_error: 0.2863 - rwrmse: 0.3814
# Epoch 88/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.2807 - mean_absolute_error: 0.2878 - rwrmse: 0.3818
# Epoch 89/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.2755 - mean_absolute_error: 0.2741 - rwrmse: 0.3634
# Epoch 90/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.2686 - mean_absolute_error: 0.2672 - rwrmse: 0.3558
# Epoch 91/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2661 - mean_absolute_error: 0.2662 - rwrmse: 0.3543
# Epoch 92/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2617 - mean_absolute_error: 0.2604 - rwrmse: 0.3465
# Epoch 93/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.2581 - mean_absolute_error: 0.2587 - rwrmse: 0.3434
# Epoch 94/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.2511 - mean_absolute_error: 0.2498 - rwrmse: 0.3309
# Epoch 95/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2454 - mean_absolute_error: 0.2455 - rwrmse: 0.3273
# Epoch 96/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2525 - mean_absolute_error: 0.2517 - rwrmse: 0.3360
# Epoch 97/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2451 - mean_absolute_error: 0.2460 - rwrmse: 0.3276
# Epoch 98/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.2407 - mean_absolute_error: 0.2395 - rwrmse: 0.3156
# Epoch 99/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.2339 - mean_absolute_error: 0.2331 - rwrmse: 0.3096
# Epoch 100/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2330 - mean_absolute_error: 0.2322 - rwrmse: 0.3073
# Epoch 101/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2275 - mean_absolute_error: 0.2270 - rwrmse: 0.3015
# Epoch 102/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.2266 - mean_absolute_error: 0.2258 - rwrmse: 0.2995
# Epoch 103/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.2244 - mean_absolute_error: 0.2241 - rwrmse: 0.2969
# Epoch 104/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2254 - mean_absolute_error: 0.2290 - rwrmse: 0.3045
# Epoch 105/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.2233 - mean_absolute_error: 0.2229 - rwrmse: 0.2942
# Epoch 106/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.2187 - mean_absolute_error: 0.2178 - rwrmse: 0.2883
# Epoch 107/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.2073 - mean_absolute_error: 0.2075 - rwrmse: 0.2769
# Epoch 108/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1999 - mean_absolute_error: 0.1998 - rwrmse: 0.2624
# Epoch 109/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1977 - mean_absolute_error: 0.1967 - rwrmse: 0.2593
# Epoch 110/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1920 - mean_absolute_error: 0.1910 - rwrmse: 0.2526
# Epoch 111/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.1887 - mean_absolute_error: 0.1882 - rwrmse: 0.2482
# Epoch 112/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1909 - mean_absolute_error: 0.1903 - rwrmse: 0.2492
# Epoch 113/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1815 - mean_absolute_error: 0.1824 - rwrmse: 0.2395
# Epoch 114/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1827 - mean_absolute_error: 0.1821 - rwrmse: 0.2371
# Epoch 115/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.1756 - mean_absolute_error: 0.1750 - rwrmse: 0.2301
# Epoch 116/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.1724 - mean_absolute_error: 0.1723 - rwrmse: 0.2268
# Epoch 117/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1719 - mean_absolute_error: 0.1719 - rwrmse: 0.2265
# Epoch 118/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1730 - mean_absolute_error: 0.1726 - rwrmse: 0.2258
# Epoch 119/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.1651 - mean_absolute_error: 0.1648 - rwrmse: 0.2171
# Epoch 120/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.1615 - mean_absolute_error: 0.1612 - rwrmse: 0.2113
# Epoch 121/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1546 - mean_absolute_error: 0.1558 - rwrmse: 0.2038
# Epoch 122/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1566 - mean_absolute_error: 0.1563 - rwrmse: 0.2052
# Epoch 123/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1516 - mean_absolute_error: 0.1511 - rwrmse: 0.1971
# Epoch 124/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.1510 - mean_absolute_error: 0.1507 - rwrmse: 0.1978
# Epoch 125/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1476 - mean_absolute_error: 0.1491 - rwrmse: 0.1959
# Epoch 126/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1482 - mean_absolute_error: 0.1485 - rwrmse: 0.1941
# Epoch 127/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1405 - mean_absolute_error: 0.1407 - rwrmse: 0.1842
# Epoch 128/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.1399 - mean_absolute_error: 0.1392 - rwrmse: 0.1819
# Epoch 129/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.1268 - mean_absolute_error: 0.1267 - rwrmse: 0.1657
# Epoch 130/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1287 - mean_absolute_error: 0.1289 - rwrmse: 0.1690
# Epoch 131/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1220 - mean_absolute_error: 0.1219 - rwrmse: 0.1596
# Epoch 132/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.1207 - mean_absolute_error: 0.1227 - rwrmse: 0.1597
# Epoch 133/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.1227 - mean_absolute_error: 0.1228 - rwrmse: 0.1588
# Epoch 134/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1207 - mean_absolute_error: 0.1202 - rwrmse: 0.1569
# Epoch 135/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1144 - mean_absolute_error: 0.1142 - rwrmse: 0.1496
# Epoch 136/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.1070 - mean_absolute_error: 0.1077 - rwrmse: 0.1407
# Epoch 137/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.1078 - mean_absolute_error: 0.1081 - rwrmse: 0.1424
# Epoch 138/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1047 - mean_absolute_error: 0.1042 - rwrmse: 0.1364
# Epoch 139/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.1024 - mean_absolute_error: 0.1030 - rwrmse: 0.1347
# Epoch 140/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.1052 - mean_absolute_error: 0.1046 - rwrmse: 0.1368
# Epoch 141/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0982 - mean_absolute_error: 0.0982 - rwrmse: 0.1289
# Epoch 142/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0960 - mean_absolute_error: 0.0958 - rwrmse: 0.1263
# Epoch 143/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0924 - mean_absolute_error: 0.0922 - rwrmse: 0.1203
# Epoch 144/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0895 - mean_absolute_error: 0.0896 - rwrmse: 0.1173
# Epoch 145/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.0850 - mean_absolute_error: 0.0849 - rwrmse: 0.1107
# Epoch 146/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0832 - mean_absolute_error: 0.0829 - rwrmse: 0.1087
# Epoch 147/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0805 - mean_absolute_error: 0.0811 - rwrmse: 0.1066
# Epoch 148/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0789 - mean_absolute_error: 0.0786 - rwrmse: 0.1028
# Epoch 149/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0758 - mean_absolute_error: 0.0757 - rwrmse: 0.0991
# Epoch 150/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0715 - mean_absolute_error: 0.0715 - rwrmse: 0.0937
# Epoch 151/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0698 - mean_absolute_error: 0.0696 - rwrmse: 0.0918
# Epoch 152/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0709 - mean_absolute_error: 0.0707 - rwrmse: 0.0934
# Epoch 153/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0664 - mean_absolute_error: 0.0661 - rwrmse: 0.0870
# Epoch 154/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0646 - mean_absolute_error: 0.0647 - rwrmse: 0.0847
# Epoch 155/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0626 - mean_absolute_error: 0.0624 - rwrmse: 0.0819
# Epoch 156/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0586 - mean_absolute_error: 0.0585 - rwrmse: 0.0767
# Epoch 157/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0583 - mean_absolute_error: 0.0585 - rwrmse: 0.0773
# Epoch 158/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.0567 - mean_absolute_error: 0.0565 - rwrmse: 0.0743
# Epoch 159/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0548 - mean_absolute_error: 0.0548 - rwrmse: 0.0722
# Epoch 160/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0517 - mean_absolute_error: 0.0518 - rwrmse: 0.0684
# Epoch 161/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0501 - mean_absolute_error: 0.0499 - rwrmse: 0.0659
# Epoch 162/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.0470 - mean_absolute_error: 0.0469 - rwrmse: 0.0621
# Epoch 163/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.0464 - mean_absolute_error: 0.0465 - rwrmse: 0.0627
# Epoch 164/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0444 - mean_absolute_error: 0.0445 - rwrmse: 0.0590
# Epoch 165/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0427 - mean_absolute_error: 0.0428 - rwrmse: 0.0564
# Epoch 166/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0393 - mean_absolute_error: 0.0393 - rwrmse: 0.0523
# Epoch 167/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0384 - mean_absolute_error: 0.0384 - rwrmse: 0.0508
# Epoch 168/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0358 - mean_absolute_error: 0.0356 - rwrmse: 0.0471
# Epoch 169/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0333 - mean_absolute_error: 0.0333 - rwrmse: 0.0442
# Epoch 170/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0321 - mean_absolute_error: 0.0320 - rwrmse: 0.0427
# Epoch 171/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0304 - mean_absolute_error: 0.0305 - rwrmse: 0.0408
# Epoch 172/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0294 - mean_absolute_error: 0.0295 - rwrmse: 0.0396
# Epoch 173/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0285 - mean_absolute_error: 0.0283 - rwrmse: 0.0378
# Epoch 174/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0261 - mean_absolute_error: 0.0262 - rwrmse: 0.0353
# Epoch 175/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0243 - mean_absolute_error: 0.0242 - rwrmse: 0.0326
# Epoch 176/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0232 - mean_absolute_error: 0.0232 - rwrmse: 0.0315
# Epoch 177/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0222 - mean_absolute_error: 0.0221 - rwrmse: 0.0299
# Epoch 178/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0209 - mean_absolute_error: 0.0208 - rwrmse: 0.0284
# Epoch 179/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0189 - mean_absolute_error: 0.0188 - rwrmse: 0.0258
# Epoch 180/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0181 - mean_absolute_error: 0.0180 - rwrmse: 0.0248
# Epoch 181/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0168 - mean_absolute_error: 0.0168 - rwrmse: 0.0232
# Epoch 182/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0158 - mean_absolute_error: 0.0159 - rwrmse: 0.0218
# Epoch 183/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0149 - mean_absolute_error: 0.0149 - rwrmse: 0.0208
# Epoch 184/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0140 - mean_absolute_error: 0.0139 - rwrmse: 0.0194
# Epoch 185/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0125 - mean_absolute_error: 0.0124 - rwrmse: 0.0175
# Epoch 186/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0117 - mean_absolute_error: 0.0116 - rwrmse: 0.0165
# Epoch 187/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0108 - mean_absolute_error: 0.0107 - rwrmse: 0.0153
# Epoch 188/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0103 - mean_absolute_error: 0.0102 - rwrmse: 0.0146
# Epoch 189/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0094 - mean_absolute_error: 0.0094 - rwrmse: 0.0136
# Epoch 190/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0088 - mean_absolute_error: 0.0088 - rwrmse: 0.0128
# Epoch 191/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0081 - mean_absolute_error: 0.0081 - rwrmse: 0.0119
# Epoch 192/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.0076 - mean_absolute_error: 0.0076 - rwrmse: 0.0112
# Epoch 193/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.0070 - mean_absolute_error: 0.0070 - rwrmse: 0.0105
# Epoch 194/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0067 - mean_absolute_error: 0.0067 - rwrmse: 0.0101
# Epoch 195/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0063 - mean_absolute_error: 0.0063 - rwrmse: 0.0096
# Epoch 196/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0059 - mean_absolute_error: 0.0059 - rwrmse: 0.0090
# Epoch 197/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.0057 - mean_absolute_error: 0.0057 - rwrmse: 0.0088
# Epoch 198/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.0054 - mean_absolute_error: 0.0054 - rwrmse: 0.0084
# Epoch 199/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0052 - mean_absolute_error: 0.0052 - rwrmse: 0.0082
# Epoch 200/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.0052 - mean_absolute_error: 0.0051 - rwrmse: 0.0081
# Epoch 201/800
# 39/39 [==============================] - 3s 83ms/step - loss: 0.2253 - mean_absolute_error: 0.2258 - rwrmse: 0.2932
# Epoch 202/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.5080 - mean_absolute_error: 0.5112 - rwrmse: 0.6721
# Epoch 203/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6311 - mean_absolute_error: 0.6287 - rwrmse: 0.8496
# Epoch 204/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4961 - mean_absolute_error: 1.4960 - rwrmse: 1.9546
# Epoch 205/800
# 39/39 [==============================] - 3s 81ms/step - loss: 11.9752 - mean_absolute_error: 11.8143 - rwrmse: 13.1623
# Epoch 206/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.9127 - mean_absolute_error: 1.9112 - rwrmse: 2.5827
# Epoch 207/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.5658 - mean_absolute_error: 1.5616 - rwrmse: 2.2373
# Epoch 208/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4760 - mean_absolute_error: 1.4839 - rwrmse: 2.1785
# Epoch 209/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.4671 - mean_absolute_error: 1.4739 - rwrmse: 2.1609
# Epoch 210/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.4383 - mean_absolute_error: 1.4317 - rwrmse: 2.1227
# Epoch 211/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4347 - mean_absolute_error: 1.4314 - rwrmse: 2.1293
# Epoch 212/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4269 - mean_absolute_error: 1.4287 - rwrmse: 2.1278
# Epoch 213/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.4242 - mean_absolute_error: 1.4177 - rwrmse: 2.1134
# Epoch 214/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.4130 - mean_absolute_error: 1.4124 - rwrmse: 2.1124
# Epoch 215/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4049 - mean_absolute_error: 1.3987 - rwrmse: 2.0981
# Epoch 216/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4039 - mean_absolute_error: 1.3993 - rwrmse: 2.0995
# Epoch 217/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.4001 - mean_absolute_error: 1.3945 - rwrmse: 2.0932
# Epoch 218/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.3959 - mean_absolute_error: 1.3954 - rwrmse: 2.0960
# Epoch 219/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3918 - mean_absolute_error: 1.3929 - rwrmse: 2.0902
# Epoch 220/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3872 - mean_absolute_error: 1.3808 - rwrmse: 2.0777
# Epoch 221/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3793 - mean_absolute_error: 1.3792 - rwrmse: 2.0811
# Epoch 222/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.3800 - mean_absolute_error: 1.3745 - rwrmse: 2.0747
# Epoch 223/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.3736 - mean_absolute_error: 1.3759 - rwrmse: 2.0807
# Epoch 224/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3692 - mean_absolute_error: 1.3721 - rwrmse: 2.0769
# Epoch 225/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3596 - mean_absolute_error: 1.3645 - rwrmse: 2.0712
# Epoch 226/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.3578 - mean_absolute_error: 1.3556 - rwrmse: 2.0556
# Epoch 227/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.3486 - mean_absolute_error: 1.3434 - rwrmse: 2.0438
# Epoch 228/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3466 - mean_absolute_error: 1.3443 - rwrmse: 2.0440
# Epoch 229/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3391 - mean_absolute_error: 1.3472 - rwrmse: 2.0503
# Epoch 230/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3361 - mean_absolute_error: 1.3434 - rwrmse: 2.0414
# Epoch 231/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.3290 - mean_absolute_error: 1.3343 - rwrmse: 2.0318
# Epoch 232/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3254 - mean_absolute_error: 1.3300 - rwrmse: 2.0335
# Epoch 233/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3228 - mean_absolute_error: 1.3255 - rwrmse: 2.0242
# Epoch 234/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3188 - mean_absolute_error: 1.3139 - rwrmse: 2.0052
# Epoch 235/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.3113 - mean_absolute_error: 1.3086 - rwrmse: 2.0008
# Epoch 236/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.3082 - mean_absolute_error: 1.3027 - rwrmse: 1.9953
# Epoch 237/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.3044 - mean_absolute_error: 1.3023 - rwrmse: 1.9955
# Epoch 238/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2982 - mean_absolute_error: 1.3027 - rwrmse: 1.9980
# Epoch 239/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.2951 - mean_absolute_error: 1.2927 - rwrmse: 1.9843
# Epoch 240/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.2846 - mean_absolute_error: 1.2825 - rwrmse: 1.9674
# Epoch 241/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2743 - mean_absolute_error: 1.2780 - rwrmse: 1.9600
# Epoch 242/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2746 - mean_absolute_error: 1.2757 - rwrmse: 1.9548
# Epoch 243/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.2653 - mean_absolute_error: 1.2626 - rwrmse: 1.9381
# Epoch 244/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.2585 - mean_absolute_error: 1.2587 - rwrmse: 1.9367
# Epoch 245/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2510 - mean_absolute_error: 1.2501 - rwrmse: 1.9220
# Epoch 246/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2445 - mean_absolute_error: 1.2448 - rwrmse: 1.9121
# Epoch 247/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2333 - mean_absolute_error: 1.2396 - rwrmse: 1.9038
# Epoch 248/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.2345 - mean_absolute_error: 1.2313 - rwrmse: 1.8926
# Epoch 249/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.2268 - mean_absolute_error: 1.2254 - rwrmse: 1.8770
# Epoch 250/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.2139 - mean_absolute_error: 1.2234 - rwrmse: 1.8745
# Epoch 251/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.1996 - mean_absolute_error: 1.1917 - rwrmse: 1.8369
# Epoch 252/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.1963 - mean_absolute_error: 1.1918 - rwrmse: 1.8319
# Epoch 253/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.1914 - mean_absolute_error: 1.1952 - rwrmse: 1.8336
# Epoch 254/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.1790 - mean_absolute_error: 1.1767 - rwrmse: 1.8075
# Epoch 255/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.1699 - mean_absolute_error: 1.1678 - rwrmse: 1.7910
# Epoch 256/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.1605 - mean_absolute_error: 1.1673 - rwrmse: 1.7909
# Epoch 257/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.1553 - mean_absolute_error: 1.1582 - rwrmse: 1.7760
# Epoch 258/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.1472 - mean_absolute_error: 1.1510 - rwrmse: 1.7596
# Epoch 259/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.1330 - mean_absolute_error: 1.1260 - rwrmse: 1.7249
# Epoch 260/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.1217 - mean_absolute_error: 1.1240 - rwrmse: 1.7218
# Epoch 261/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.1207 - mean_absolute_error: 1.1166 - rwrmse: 1.7057
# Epoch 262/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.1150 - mean_absolute_error: 1.1121 - rwrmse: 1.6973
# Epoch 263/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.1037 - mean_absolute_error: 1.1007 - rwrmse: 1.6789
# Epoch 264/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.0946 - mean_absolute_error: 1.0904 - rwrmse: 1.6630
# Epoch 265/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.0787 - mean_absolute_error: 1.0715 - rwrmse: 1.6364
# Epoch 266/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.0677 - mean_absolute_error: 1.0720 - rwrmse: 1.6382
# Epoch 267/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.0668 - mean_absolute_error: 1.0716 - rwrmse: 1.6302
# Epoch 268/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.0528 - mean_absolute_error: 1.0548 - rwrmse: 1.6035
# Epoch 269/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.0486 - mean_absolute_error: 1.0405 - rwrmse: 1.5833
# Epoch 270/800
# 39/39 [==============================] - 3s 81ms/step - loss: 1.0389 - mean_absolute_error: 1.0513 - rwrmse: 1.6017
# Epoch 271/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.0359 - mean_absolute_error: 1.0504 - rwrmse: 1.5955
# Epoch 272/800
# 39/39 [==============================] - 3s 79ms/step - loss: 1.0244 - mean_absolute_error: 1.0214 - rwrmse: 1.5521
# Epoch 273/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.0191 - mean_absolute_error: 1.0242 - rwrmse: 1.5541
# Epoch 274/800
# 39/39 [==============================] - 3s 82ms/step - loss: 1.0136 - mean_absolute_error: 1.0210 - rwrmse: 1.5517
# Epoch 275/800
# 39/39 [==============================] - 3s 80ms/step - loss: 1.0037 - mean_absolute_error: 1.0013 - rwrmse: 1.5223
# Epoch 276/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9937 - mean_absolute_error: 0.9923 - rwrmse: 1.5055
# Epoch 277/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.9927 - mean_absolute_error: 0.9878 - rwrmse: 1.4960
# Epoch 278/800
# 39/39 [==============================] - 3s 83ms/step - loss: 0.9775 - mean_absolute_error: 0.9763 - rwrmse: 1.4852
# Epoch 279/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9721 - mean_absolute_error: 0.9838 - rwrmse: 1.4936
# Epoch 280/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9691 - mean_absolute_error: 0.9808 - rwrmse: 1.4891
# Epoch 281/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9611 - mean_absolute_error: 0.9749 - rwrmse: 1.4839
# Epoch 282/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.9542 - mean_absolute_error: 0.9549 - rwrmse: 1.4473
# Epoch 283/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9385 - mean_absolute_error: 0.9446 - rwrmse: 1.4422
# Epoch 284/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9361 - mean_absolute_error: 0.9477 - rwrmse: 1.4432
# Epoch 285/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.9328 - mean_absolute_error: 0.9324 - rwrmse: 1.4186
# Epoch 286/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.9259 - mean_absolute_error: 0.9278 - rwrmse: 1.4135
# Epoch 287/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.9275 - mean_absolute_error: 0.9288 - rwrmse: 1.4112
# Epoch 288/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.9173 - mean_absolute_error: 0.9191 - rwrmse: 1.4014
# Epoch 289/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9092 - mean_absolute_error: 0.9158 - rwrmse: 1.3949
# Epoch 290/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.9013 - mean_absolute_error: 0.9123 - rwrmse: 1.3910
# Epoch 291/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.8967 - mean_absolute_error: 0.9071 - rwrmse: 1.3824
# Epoch 292/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.8907 - mean_absolute_error: 0.8929 - rwrmse: 1.3644
# Epoch 293/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8837 - mean_absolute_error: 0.8788 - rwrmse: 1.3422
# Epoch 294/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8806 - mean_absolute_error: 0.8789 - rwrmse: 1.3465
# Epoch 295/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.8712 - mean_absolute_error: 0.8655 - rwrmse: 1.3246
# Epoch 296/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.8653 - mean_absolute_error: 0.8582 - rwrmse: 1.3135
# Epoch 297/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8615 - mean_absolute_error: 0.8553 - rwrmse: 1.3121
# Epoch 298/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.8587 - mean_absolute_error: 0.8518 - rwrmse: 1.3054
# Epoch 299/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.8500 - mean_absolute_error: 0.8434 - rwrmse: 1.2923
# Epoch 300/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.8447 - mean_absolute_error: 0.8514 - rwrmse: 1.3043
# Epoch 301/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8437 - mean_absolute_error: 0.8408 - rwrmse: 1.2864
# Epoch 302/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.8339 - mean_absolute_error: 0.8355 - rwrmse: 1.2810
# Epoch 303/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.8290 - mean_absolute_error: 0.8313 - rwrmse: 1.2773
# Epoch 304/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.8202 - mean_absolute_error: 0.8244 - rwrmse: 1.2685
# Epoch 305/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.8161 - mean_absolute_error: 0.8103 - rwrmse: 1.2483
# Epoch 306/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.8155 - mean_absolute_error: 0.8109 - rwrmse: 1.2458
# Epoch 307/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.8094 - mean_absolute_error: 0.8056 - rwrmse: 1.2429
# Epoch 308/800
# 39/39 [==============================] - 3s 83ms/step - loss: 0.8108 - mean_absolute_error: 0.8076 - rwrmse: 1.2417
# Epoch 309/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.8014 - mean_absolute_error: 0.7949 - rwrmse: 1.2257
# Epoch 310/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7910 - mean_absolute_error: 0.7928 - rwrmse: 1.2270
# Epoch 311/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7848 - mean_absolute_error: 0.7809 - rwrmse: 1.2112
# Epoch 312/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.7765 - mean_absolute_error: 0.7784 - rwrmse: 1.2075
# Epoch 313/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.7796 - mean_absolute_error: 0.7855 - rwrmse: 1.2175
# Epoch 314/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7745 - mean_absolute_error: 0.7846 - rwrmse: 1.2172
# Epoch 315/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7684 - mean_absolute_error: 0.7744 - rwrmse: 1.2029
# Epoch 316/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.7670 - mean_absolute_error: 0.7652 - rwrmse: 1.1877
# Epoch 317/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.7564 - mean_absolute_error: 0.7578 - rwrmse: 1.1810
# Epoch 318/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.7516 - mean_absolute_error: 0.7520 - rwrmse: 1.1728
# Epoch 319/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7481 - mean_absolute_error: 0.7480 - rwrmse: 1.1665
# Epoch 320/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7429 - mean_absolute_error: 0.7482 - rwrmse: 1.1690
# Epoch 321/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.7388 - mean_absolute_error: 0.7343 - rwrmse: 1.1477
# Epoch 322/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7364 - mean_absolute_error: 0.7429 - rwrmse: 1.1626
# Epoch 323/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7323 - mean_absolute_error: 0.7265 - rwrmse: 1.1356
# Epoch 324/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.7263 - mean_absolute_error: 0.7216 - rwrmse: 1.1309
# Epoch 325/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.7232 - mean_absolute_error: 0.7181 - rwrmse: 1.1256
# Epoch 326/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7215 - mean_absolute_error: 0.7242 - rwrmse: 1.1351
# Epoch 327/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.7168 - mean_absolute_error: 0.7116 - rwrmse: 1.1179
# Epoch 328/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.7125 - mean_absolute_error: 0.7136 - rwrmse: 1.1212
# Epoch 329/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.7074 - mean_absolute_error: 0.7163 - rwrmse: 1.1293
# Epoch 330/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.7022 - mean_absolute_error: 0.6990 - rwrmse: 1.1036
# Epoch 331/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6980 - mean_absolute_error: 0.6960 - rwrmse: 1.1022
# Epoch 332/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6957 - mean_absolute_error: 0.6906 - rwrmse: 1.0924
# Epoch 333/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6876 - mean_absolute_error: 0.6945 - rwrmse: 1.1053
# Epoch 334/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6851 - mean_absolute_error: 0.6804 - rwrmse: 1.0794
# Epoch 335/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6805 - mean_absolute_error: 0.6817 - rwrmse: 1.0840
# Epoch 336/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6772 - mean_absolute_error: 0.6708 - rwrmse: 1.0686
# Epoch 337/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6761 - mean_absolute_error: 0.6773 - rwrmse: 1.0778
# Epoch 338/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6700 - mean_absolute_error: 0.6647 - rwrmse: 1.0613
# Epoch 339/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6671 - mean_absolute_error: 0.6710 - rwrmse: 1.0724
# Epoch 340/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6637 - mean_absolute_error: 0.6632 - rwrmse: 1.0641
# Epoch 341/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6605 - mean_absolute_error: 0.6574 - rwrmse: 1.0546
# Epoch 342/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6558 - mean_absolute_error: 0.6513 - rwrmse: 1.0459
# Epoch 343/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6529 - mean_absolute_error: 0.6539 - rwrmse: 1.0514
# Epoch 344/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6517 - mean_absolute_error: 0.6477 - rwrmse: 1.0429
# Epoch 345/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6454 - mean_absolute_error: 0.6601 - rwrmse: 1.0679
# Epoch 346/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6424 - mean_absolute_error: 0.6477 - rwrmse: 1.0480
# Epoch 347/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6401 - mean_absolute_error: 0.6437 - rwrmse: 1.0414
# Epoch 348/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6369 - mean_absolute_error: 0.6348 - rwrmse: 1.0319
# Epoch 349/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6350 - mean_absolute_error: 0.6314 - rwrmse: 1.0241
# Epoch 350/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.6318 - mean_absolute_error: 0.6326 - rwrmse: 1.0307
# Epoch 351/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6293 - mean_absolute_error: 0.6263 - rwrmse: 1.0190
# Epoch 352/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6265 - mean_absolute_error: 0.6348 - rwrmse: 1.0329
# Epoch 353/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.6228 - mean_absolute_error: 0.6243 - rwrmse: 1.0188
# Epoch 354/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6212 - mean_absolute_error: 0.6169 - rwrmse: 1.0072
# Epoch 355/800
# 39/39 [==============================] - 3s 83ms/step - loss: 0.6181 - mean_absolute_error: 0.6143 - rwrmse: 1.0054
# Epoch 356/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6158 - mean_absolute_error: 0.6107 - rwrmse: 1.0022
# Epoch 357/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6132 - mean_absolute_error: 0.6112 - rwrmse: 1.0032
# Epoch 358/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6102 - mean_absolute_error: 0.6089 - rwrmse: 1.0051
# Epoch 359/800
# 39/39 [==============================] - 3s 82ms/step - loss: 0.6077 - mean_absolute_error: 0.6075 - rwrmse: 1.0011
# Epoch 360/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.6052 - mean_absolute_error: 0.6048 - rwrmse: 0.9992
# Epoch 361/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6020 - mean_absolute_error: 0.5983 - rwrmse: 0.9898
# Epoch 362/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.6009 - mean_absolute_error: 0.5985 - rwrmse: 0.9914
# Epoch 363/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.5986 - mean_absolute_error: 0.5937 - rwrmse: 0.9835
# Epoch 364/800
# 39/39 [==============================] - 3s 81ms/step - loss: 0.5960 - mean_absolute_error: 0.5978 - rwrmse: 0.9924
# Epoch 365/800
# 39/39 [==============================] - 3s 79ms/step - loss: 0.5939 - mean_absolute_error: 0.5945 - rwrmse: 0.9877
# Epoch 366/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.5928 - mean_absolute_error: 0.5882 - rwrmse: 0.9785
# Epoch 367/800
# 39/39 [==============================] - 3s 80ms/step - loss: 0.5905 - mean_absolute_error: 0.5871 - rwrmse: 0.9785
# Epoch 368/800
# ...
# Epoch 680/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.2061 - mean_absolute_error: 0.2069 - rwrmse: 0.3155
# Epoch 681/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.2139 - mean_absolute_error: 0.2135 - rwrmse: 0.3212
# Epoch 682/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.2068 - mean_absolute_error: 0.2085 - rwrmse: 0.3186
# Epoch 683/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.2071 - mean_absolute_error: 0.2066 - rwrmse: 0.3132
# Epoch 684/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.2043 - mean_absolute_error: 0.2037 - rwrmse: 0.3098
# Epoch 685/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.2056 - mean_absolute_error: 0.2057 - rwrmse: 0.3113
# Epoch 686/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.2042 - mean_absolute_error: 0.2042 - rwrmse: 0.3086
# Epoch 687/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.2055 - mean_absolute_error: 0.2050 - rwrmse: 0.3103
# Epoch 688/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.2006 - mean_absolute_error: 0.2015 - rwrmse: 0.3069
# Epoch 689/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1991 - mean_absolute_error: 0.1995 - rwrmse: 0.3022
# Epoch 690/800
# 39/39 [==============================] - 5s 117ms/step - loss: 0.2004 - mean_absolute_error: 0.1999 - rwrmse: 0.3014
# Epoch 691/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1894 - mean_absolute_error: 0.1889 - rwrmse: 0.2898
# Epoch 692/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1870 - mean_absolute_error: 0.1865 - rwrmse: 0.2868
# Epoch 693/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1867 - mean_absolute_error: 0.1876 - rwrmse: 0.2894
# Epoch 694/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1877 - mean_absolute_error: 0.1874 - rwrmse: 0.2881
# Epoch 695/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.1828 - mean_absolute_error: 0.1822 - rwrmse: 0.2799
# Epoch 696/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1792 - mean_absolute_error: 0.1786 - rwrmse: 0.2758
# Epoch 697/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.1789 - mean_absolute_error: 0.1786 - rwrmse: 0.2759
# Epoch 698/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1780 - mean_absolute_error: 0.1774 - rwrmse: 0.2747
# Epoch 699/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1755 - mean_absolute_error: 0.1754 - rwrmse: 0.2719
# Epoch 700/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1754 - mean_absolute_error: 0.1749 - rwrmse: 0.2711
# Epoch 701/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1713 - mean_absolute_error: 0.1722 - rwrmse: 0.2698
# Epoch 702/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1696 - mean_absolute_error: 0.1697 - rwrmse: 0.2640
# Epoch 703/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1701 - mean_absolute_error: 0.1695 - rwrmse: 0.2626
# Epoch 704/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1662 - mean_absolute_error: 0.1660 - rwrmse: 0.2593
# Epoch 705/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1672 - mean_absolute_error: 0.1667 - rwrmse: 0.2596
# Epoch 706/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1626 - mean_absolute_error: 0.1629 - rwrmse: 0.2566
# Epoch 707/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1633 - mean_absolute_error: 0.1626 - rwrmse: 0.2543
# Epoch 708/800
# 39/39 [==============================] - 5s 121ms/step - loss: 0.1613 - mean_absolute_error: 0.1612 - rwrmse: 0.2526
# Epoch 709/800
# 39/39 [==============================] - 4s 114ms/step - loss: 0.1584 - mean_absolute_error: 0.1582 - rwrmse: 0.2498
# Epoch 710/800
# 39/39 [==============================] - 4s 114ms/step - loss: 0.1591 - mean_absolute_error: 0.1585 - rwrmse: 0.2505
# Epoch 711/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1573 - mean_absolute_error: 0.1569 - rwrmse: 0.2475
# Epoch 712/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1568 - mean_absolute_error: 0.1570 - rwrmse: 0.2481
# Epoch 713/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.1503 - mean_absolute_error: 0.1496 - rwrmse: 0.2382
# Epoch 714/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1521 - mean_absolute_error: 0.1515 - rwrmse: 0.2409
# Epoch 715/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1468 - mean_absolute_error: 0.1465 - rwrmse: 0.2342
# Epoch 716/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1455 - mean_absolute_error: 0.1453 - rwrmse: 0.2339
# Epoch 717/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1440 - mean_absolute_error: 0.1443 - rwrmse: 0.2322
# Epoch 718/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1444 - mean_absolute_error: 0.1441 - rwrmse: 0.2314
# Epoch 719/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.1446 - mean_absolute_error: 0.1449 - rwrmse: 0.2338
# Epoch 720/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1410 - mean_absolute_error: 0.1406 - rwrmse: 0.2268
# Epoch 721/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1372 - mean_absolute_error: 0.1371 - rwrmse: 0.2249
# Epoch 722/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1381 - mean_absolute_error: 0.1382 - rwrmse: 0.2250
# Epoch 723/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1349 - mean_absolute_error: 0.1350 - rwrmse: 0.2232
# Epoch 724/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1340 - mean_absolute_error: 0.1343 - rwrmse: 0.2219
# Epoch 725/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1316 - mean_absolute_error: 0.1315 - rwrmse: 0.2161
# Epoch 726/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1297 - mean_absolute_error: 0.1295 - rwrmse: 0.2143
# Epoch 727/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.1284 - mean_absolute_error: 0.1280 - rwrmse: 0.2124
# Epoch 728/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1281 - mean_absolute_error: 0.1279 - rwrmse: 0.2122
# Epoch 729/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1264 - mean_absolute_error: 0.1262 - rwrmse: 0.2104
# Epoch 730/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1248 - mean_absolute_error: 0.1248 - rwrmse: 0.2086
# Epoch 731/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1223 - mean_absolute_error: 0.1222 - rwrmse: 0.2070
# Epoch 732/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1206 - mean_absolute_error: 0.1207 - rwrmse: 0.2045
# Epoch 733/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1181 - mean_absolute_error: 0.1183 - rwrmse: 0.2021
# Epoch 734/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1173 - mean_absolute_error: 0.1178 - rwrmse: 0.2024
# Epoch 735/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1163 - mean_absolute_error: 0.1163 - rwrmse: 0.1992
# Epoch 736/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1165 - mean_absolute_error: 0.1160 - rwrmse: 0.1979
# Epoch 737/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1128 - mean_absolute_error: 0.1127 - rwrmse: 0.1952
# Epoch 738/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1122 - mean_absolute_error: 0.1120 - rwrmse: 0.1939
# Epoch 739/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1104 - mean_absolute_error: 0.1117 - rwrmse: 0.1978
# Epoch 740/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.1097 - mean_absolute_error: 0.1098 - rwrmse: 0.1931
# Epoch 741/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.1076 - mean_absolute_error: 0.1073 - rwrmse: 0.1885
# Epoch 742/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1060 - mean_absolute_error: 0.1057 - rwrmse: 0.1872
# Epoch 743/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1048 - mean_absolute_error: 0.1045 - rwrmse: 0.1852
# Epoch 744/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1038 - mean_absolute_error: 0.1037 - rwrmse: 0.1856
# Epoch 745/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.1015 - mean_absolute_error: 0.1014 - rwrmse: 0.1820
# Epoch 746/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.1005 - mean_absolute_error: 0.1002 - rwrmse: 0.1812
# Epoch 747/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.1000 - mean_absolute_error: 0.1006 - rwrmse: 0.1841
# Epoch 748/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0979 - mean_absolute_error: 0.0983 - rwrmse: 0.1791
# Epoch 749/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0971 - mean_absolute_error: 0.0967 - rwrmse: 0.1769
# Epoch 750/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.0958 - mean_absolute_error: 0.0955 - rwrmse: 0.1756
# Epoch 751/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0939 - mean_absolute_error: 0.0936 - rwrmse: 0.1739
# Epoch 752/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0931 - mean_absolute_error: 0.0927 - rwrmse: 0.1727
# Epoch 753/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.0927 - mean_absolute_error: 0.0924 - rwrmse: 0.1730
# Epoch 754/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - rwrmse: 0.1727
# Epoch 755/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0909 - mean_absolute_error: 0.0906 - rwrmse: 0.1714
# Epoch 756/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.0890 - mean_absolute_error: 0.0920 - rwrmse: 0.1782
# Epoch 757/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0889 - mean_absolute_error: 0.0892 - rwrmse: 0.1712
# Epoch 758/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0873 - mean_absolute_error: 0.0868 - rwrmse: 0.1669
# Epoch 759/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.0864 - mean_absolute_error: 0.0860 - rwrmse: 0.1662
# Epoch 760/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0856 - mean_absolute_error: 0.0853 - rwrmse: 0.1656
# Epoch 761/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0850 - mean_absolute_error: 0.0845 - rwrmse: 0.1648
# Epoch 762/800
# 39/39 [==============================] - 5s 120ms/step - loss: 0.0835 - mean_absolute_error: 0.0834 - rwrmse: 0.1653
# Epoch 763/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.0823 - mean_absolute_error: 0.0823 - rwrmse: 0.1634
# Epoch 764/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0815 - mean_absolute_error: 0.0811 - rwrmse: 0.1620
# Epoch 765/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.0812 - mean_absolute_error: 0.0813 - rwrmse: 0.1625
# Epoch 766/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0797 - mean_absolute_error: 0.0796 - rwrmse: 0.1606
# Epoch 767/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0789 - mean_absolute_error: 0.0788 - rwrmse: 0.1594
# Epoch 768/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.0779 - mean_absolute_error: 0.0781 - rwrmse: 0.1595
# Epoch 769/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.0775 - mean_absolute_error: 0.0770 - rwrmse: 0.1577
# Epoch 770/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0772 - mean_absolute_error: 0.0772 - rwrmse: 0.1582
# Epoch 771/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.0764 - mean_absolute_error: 0.0763 - rwrmse: 0.1573
# Epoch 772/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0752 - mean_absolute_error: 0.0749 - rwrmse: 0.1562
# Epoch 773/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0746 - mean_absolute_error: 0.0745 - rwrmse: 0.1559
# Epoch 774/800
# 39/39 [==============================] - 5s 119ms/step - loss: 0.0737 - mean_absolute_error: 0.0731 - rwrmse: 0.1543
# Epoch 775/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0736 - mean_absolute_error: 0.0733 - rwrmse: 0.1547
# Epoch 776/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0727 - mean_absolute_error: 0.0727 - rwrmse: 0.1546
# Epoch 777/800
# 39/39 [==============================] - 5s 117ms/step - loss: 0.0720 - mean_absolute_error: 0.0728 - rwrmse: 0.1592
# Epoch 778/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0712 - mean_absolute_error: 0.0717 - rwrmse: 0.1569
# Epoch 779/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0708 - mean_absolute_error: 0.0708 - rwrmse: 0.1526
# Epoch 780/800
# 39/39 [==============================] - 5s 117ms/step - loss: 0.0702 - mean_absolute_error: 0.0700 - rwrmse: 0.1534
# Epoch 781/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0699 - mean_absolute_error: 0.0701 - rwrmse: 0.1526
# Epoch 782/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0691 - mean_absolute_error: 0.0691 - rwrmse: 0.1513
# Epoch 783/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.0687 - mean_absolute_error: 0.0690 - rwrmse: 0.1541
# Epoch 784/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0683 - mean_absolute_error: 0.0683 - rwrmse: 0.1509
# Epoch 785/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0679 - mean_absolute_error: 0.0675 - rwrmse: 0.1498
# Epoch 786/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.0676 - mean_absolute_error: 0.0675 - rwrmse: 0.1505
# Epoch 787/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0671 - mean_absolute_error: 0.0671 - rwrmse: 0.1498
# Epoch 788/800
# 39/39 [==============================] - 4s 112ms/step - loss: 0.0668 - mean_absolute_error: 0.0667 - rwrmse: 0.1494
# Epoch 789/800
# 39/39 [==============================] - 5s 118ms/step - loss: 0.0664 - mean_absolute_error: 0.0664 - rwrmse: 0.1495
# Epoch 790/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.0661 - mean_absolute_error: 0.0659 - rwrmse: 0.1487
# Epoch 791/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0661 - mean_absolute_error: 0.0668 - rwrmse: 0.1551
# Epoch 792/800
# 39/39 [==============================] - 5s 117ms/step - loss: 0.0658 - mean_absolute_error: 0.0656 - rwrmse: 0.1487
# Epoch 793/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - rwrmse: 0.1490
# Epoch 794/800
# 39/39 [==============================] - 4s 110ms/step - loss: 0.0653 - mean_absolute_error: 0.0652 - rwrmse: 0.1484
# Epoch 795/800
# 39/39 [==============================] - 5s 117ms/step - loss: 0.0651 - mean_absolute_error: 0.0649 - rwrmse: 0.1483
# Epoch 796/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0648 - mean_absolute_error: 0.0646 - rwrmse: 0.1487
# Epoch 797/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0647 - mean_absolute_error: 0.0644 - rwrmse: 0.1477
# Epoch 798/800
# 39/39 [==============================] - 5s 117ms/step - loss: 0.0646 - mean_absolute_error: 0.0644 - rwrmse: 0.1477
# Epoch 799/800
# 39/39 [==============================] - 4s 113ms/step - loss: 0.0645 - mean_absolute_error: 0.0642 - rwrmse: 0.1478
# Epoch 800/800
# 39/39 [==============================] - 4s 111ms/step - loss: 0.0645 - mean_absolute_error: 0.0662 - rwrmse: 0.1551
#
# Epoch 00801: final model weights set to stochastic weight average

# %%
# Load in submission set
df_id = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Input/singlecell/id_map_submission.csv')

# Convert to Morgan fingerprints
df_X = np.zeros([df_id.shape[0], 2048])
for i in range(df_id.shape[0]):
	df_X[i, :] = np.array(AllChem.GetMorganFingerprintAsBitVect(Chem.MolFromSmiles(df_id["SMILES"][i]), radius=2, nBits=2048))

# One hot encode the cell types
n_cell_types = 6
cells = ["B cells", "Myeloid cells", "NK cells", "T cells CD4+", "T cells CD8+", "T regulatory cells"]
one_hot = pd.DataFrame(np.zeros([df_id.shape[0], n_cell_types]), columns=cells)

# Fill in one_hot
one_hot_test = pd.get_dummies(df_id["cell_type"]) * 1.0
one_hot["B cells"] = one_hot_test["B cells"]
one_hot["Myeloid cells"] = one_hot_test["Myeloid cells"]
one_hot = np.array(one_hot)

# Control and dose for test
# Control (1 - control, 0 - non-control)
# No control compounds in test, all values should be 0
test_control = np.zeros([df_id.shape[0], 1])

# Dose (1 uM for all compounds). All compounds in train were 1 uM except for Belinostat
test_dose = np.ones([df_id.shape[0], 1])

# Log10 transform n_atoms, molecular weight, and molar refractivity
df_id["n_atoms"] = df_id["n_atoms"].map(np.log10)
df_id["mol_weight"] = df_id["mol_weight"].map(np.log10)
df_id["MR"] = df_id["MR"].map(np.log10)

# Merge to construct test matrix
one_hot = np.concatenate((one_hot, scaler.transform(df_id[["log_P", "MR"]]), test_control), axis=1)
x_test = np.concatenate((one_hot, df_X), axis=1)

del one_hot, one_hot_test

# %%
# Augment features with average drug response and average cell type response to drugs for test

if drug_response:
  df_id_alt = df_id.iloc[:, 0:5]
  df_id_alt = df_id_alt.merge(mean_smiles_name, on='SMILES', how='left')
  mean_smiles_test = np.array(df_id_alt.iloc[:, 5:])
  # Concat with x_test
  x_test = np.concatenate((x_test, scaler_drug.transform(mean_smiles_test)), axis=1)

if cell_type_response:
  df_id_alt = df_id.iloc[:, 0:5]
  df_id_alt = df_id_alt.merge(mean_cell_type, on='cell_type', how='left')
  mean_cell_test = np.array(df_id_alt.iloc[:, 5:])
  # Concat with x_Test
  x_test = np.concatenate((x_test, scaler_cell.transform(mean_cell_test)), axis=1)

if drug_lfc_response:
  df_id_alt = df_id.iloc[:, 0:5]
  df_id_alt = df_id_alt.merge(mean_smiles_lfc_name, on='SMILES', how='left')
  mean_smiles_lfc_test = np.array(df_id_alt.iloc[:, 5:])
  # Concat with x_test
  x_test = np.concatenate((x_test, scaler_drug_lfc.transform(mean_smiles_lfc_test)), axis=1)

if cell_type_lfc_response:
  df_id_alt = df_id.iloc[:, 0:5]
  df_id_alt = df_id_alt.merge(mean_cell_lfc_type, on='cell_type', how='left')
  mean_cell_lfc_test = np.array(df_id_alt.iloc[:, 5:])
  # Concat with x_test
  x_test = np.concatenate((x_test, scaler_cell_lfc.transform(mean_cell_lfc_test)), axis=1)

# %%
x_test.shape
# Out:
# (255, 2057)

# %%
# Predict
output_emb = model.predict(x_test)

# Standard scaled SVD embed
if y_train_scale:
  if run_svd:
    output_high = scaler_y_embed.inverse_transform(output_emb) @ VT
  if run_autoencoder:
    output_high = decoder.predict(scaler_y_embed.inverse_transform(output_emb))
else:
  # Normal SVD embed
  if run_svd:
    output_high = output_emb @ VT
  if run_autoencoder:
    output_high = decoder.predict(output_emb)

# Read in submission file
submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Input/singlecell/sample_submission.csv')
submission.iloc[:, 1:] = output_high
# Out:
# 8/8 [==============================] - 0s 9ms/step

# %%
np.max(output_emb), np.min(output_emb)
# Out:
# (15.223473, -13.507002)

# %%
np.max(output_high), np.min(output_high)
# Out:
# (65.74404806279857, -42.696321795331656)

# %%
# Save as submission
# Generate truncated SHA256 hash
truncated_hash = hashlib.sha256(os.urandom(23)).hexdigest()[:23]

submission_path = '/content/drive/MyDrive/Colab Notebooks/Output/ecfp_reg_8lselu_stack_v289_' + truncated_hash + '.csv'
submission.to_csv(submission_path, index=False)

# Print hash
print(truncated_hash)
# Out:
# 52f7b670061d957ae6c6cee

# %%
# Calculuate rwrmse for original y_train

if y_train_scale:
  if run_svd:
    y_train_pred = scaler_y_embed.inverse_transform(model.predict(x_train_copy)) @ VT
  if run_autoencoder:
    y_train_pred = decoder.predict(scaler_y_embed.inverse_transform(model.predict(x_train_copy)))
else:
  if run_svd:
    y_train_pred = model.predict(x_train_copy) @ VT
  if run_autoencoder:
    y_train_pred = decoder.predict(model.predict(x_train_copy))

train_loss = K.eval(rwrmse(y_train_copy, y_train_pred))
train_loss
# Out:
# 20/20 [==============================] - 0s 8ms/step
# 0.5746691873989737

# %%
# Save predictions on train
filepath = '/content/drive/MyDrive/Colab Notebooks/Train Predictions/train_predictions_' + 'v289_' + truncated_hash + '.csv'
y_train_pred = pd.DataFrame(y_train_pred)

# Save as csv
y_train_pred.to_csv(filepath, index=False)

# %%
# Save model
# Use .keras extension to save whole model
filepath = '/content/drive/MyDrive/Colab Notebooks/Models/ecfp_reg_8lselu_stack_v289_' + truncated_hash + '.keras'
model.save(filepath)
